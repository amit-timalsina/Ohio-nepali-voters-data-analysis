# %%
! mkdir data; cd data ; for i in {71..88}; do wget https://www6.ohiosos.gov/ords/f?p=VOTERFTP:DOWNLOAD::FILE:NO:2:P2_PRODUCT_NUMBER:${i}; done
# Out:
# mkdir: cannot create directory ‘data’: File exists
# --2021-06-01 10:55:09--  https://www6.ohiosos.gov/ords/f?p=VOTERFTP:DOWNLOAD::FILE:NO:2:P2_PRODUCT_NUMBER:71
# Resolving www6.ohiosos.gov (www6.ohiosos.gov)... 104.16.134.50, 104.16.135.50
# Connecting to www6.ohiosos.gov (www6.ohiosos.gov)|104.16.134.50|:443... connected.
# HTTP request sent, awaiting response... 200
# Length: 25512360 (24M) [application/octet]
# Saving to: ‘f?p=VOTERFTP:DOWNLOAD::FILE:NO:2:P2_PRODUCT_NUMBER:71’
#
# f?p=VOTERFTP:DOWNLO 100%[===================>]  24.33M  24.9MB/s    in 1.0s
#
# 2021-06-01 10:55:10 (24.9 MB/s) - ‘f?p=VOTERFTP:DOWNLOAD::FILE:NO:2:P2_PRODUCT_NUMBER:71’ saved [25512360/25512360]
#
# --2021-06-01 10:55:10--  https://www6.ohiosos.gov/ords/f?p=VOTERFTP:DOWNLOAD::FILE:NO:2:P2_PRODUCT_NUMBER:72
# Resolving www6.ohiosos.gov (www6.ohiosos.gov)... 104.16.134.50, 104.16.135.50
# Connecting to www6.ohiosos.gov (www6.ohiosos.gov)|104.16.134.50|:443... connected.
# HTTP request sent, awaiting response... 200
# Length: 20726882 (20M) [application/octet]
# Saving to: ‘f?p=VOTERFTP:DOWNLOAD::FILE:NO:2:P2_PRODUCT_NUMBER:72’
#
# f?p=VOTERFTP:DOWNLO 100%[===================>]  19.77M  22.8MB/s    in 0.9s
#
# 2021-06-01 10:55:11 (22.8 MB/s) - ‘f?p=VOTERFTP:DOWNLOAD::FILE:NO:2:P2_PRODUCT_NUMBER:72’ saved [20726882/20726882]
#
# --2021-06-01 10:55:11--  https://www6.ohiosos.gov/ords/f?p=VOTERFTP:DOWNLOAD::FILE:NO:2:P2_PRODUCT_NUMBER:73
# Resolving www6.ohiosos.gov (www6.ohiosos.gov)... 104.16.134.50, 104.16.135.50
# Connecting to www6.ohiosos.gov (www6.ohiosos.gov)|104.16.134.50|:443... connected.
# HTTP request sent, awaiting response... 200
# Length: 25849109 (25M) [application/octet]
# Saving to: ‘f?p=VOTERFTP:DOWNLOAD::FILE:NO:2:P2_PRODUCT_NUMBER:73’
#
# f?p=VOTERFTP:DOWNLO 100%[===================>]  24.65M  24.4MB/s    in 1.0s
#
# 2021-06-01 10:55:13 (24.4 MB/s) - ‘f?p=VOTERFTP:DOWNLOAD::FILE:NO:2:P2_PRODUCT_NUMBER:73’ saved [25849109/25849109]
#
# --2021-06-01 10:55:13--  https://www6.ohiosos.gov/ords/f?p=VOTERFTP:DOWNLOAD::FILE:NO:2:P2_PRODUCT_NUMBER:74
# Resolving www6.ohiosos.gov (www6.ohiosos.gov)... 104.16.134.50, 104.16.135.50
# Connecting to www6.ohiosos.gov (www6.ohiosos.gov)|104.16.134.50|:443... connected.
# HTTP request sent, awaiting response... 200
# Length: 17809598 (17M) [application/octet]
# Saving to: ‘f?p=VOTERFTP:DOWNLOAD::FILE:NO:2:P2_PRODUCT_NUMBER:74’
#
# f?p=VOTERFTP:DOWNLO 100%[===================>]  16.98M  24.5MB/s    in 0.7s
#
# 2021-06-01 10:55:14 (24.5 MB/s) - ‘f?p=VOTERFTP:DOWNLOAD::FILE:NO:2:P2_PRODUCT_NUMBER:74’ saved [17809598/17809598]
#
# --2021-06-01 10:55:14--  https://www6.ohiosos.gov/ords/f?p=VOTERFTP:DOWNLOAD::FILE:NO:2:P2_PRODUCT_NUMBER:75
# Resolving www6.ohiosos.gov (www6.ohiosos.gov)... 104.16.135.50, 104.16.134.50
# Connecting to www6.ohiosos.gov (www6.ohiosos.gov)|104.16.135.50|:443... connected.
# HTTP request sent, awaiting response... 200
# Length: 18171395 (17M) [application/octet]
# Saving to: ‘f?p=VOTERFTP:DOWNLOAD::FILE:NO:2:P2_PRODUCT_NUMBER:75’
#
# f?p=VOTERFTP:DOWNLO 100%[===================>]  17.33M  23.8MB/s    in 0.7s
#
# 2021-06-01 10:55:15 (23.8 MB/s) - ‘f?p=VOTERFTP:DOWNLOAD::FILE:NO:2:P2_PRODUCT_NUMBER:75’ saved [18171395/18171395]
#
# --2021-06-01 10:55:15--  https://www6.ohiosos.gov/ords/f?p=VOTERFTP:DOWNLOAD::FILE:NO:2:P2_PRODUCT_NUMBER:76
# Resolving www6.ohiosos.gov (www6.ohiosos.gov)... 104.16.135.50, 104.16.134.50
# Connecting to www6.ohiosos.gov (www6.ohiosos.gov)|104.16.135.50|:443... connected.
# HTTP request sent, awaiting response... 200
# Length: 131723312 (126M) [application/octet]
# Saving to: ‘f?p=VOTERFTP:DOWNLOAD::FILE:NO:2:P2_PRODUCT_NUMBER:76’
#
# f?p=VOTERFTP:DOWNLO 100%[===================>] 125.62M  27.5MB/s    in 4.7s
#
# 2021-06-01 10:55:20 (26.5 MB/s) - ‘f?p=VOTERFTP:DOWNLOAD::FILE:NO:2:P2_PRODUCT_NUMBER:76’ saved [131723312/131723312]
#
# --2021-06-01 10:55:20--  https://www6.ohiosos.gov/ords/f?p=VOTERFTP:DOWNLOAD::FILE:NO:2:P2_PRODUCT_NUMBER:77
# Resolving www6.ohiosos.gov (www6.ohiosos.gov)... 104.16.134.50, 104.16.135.50
# Connecting to www6.ohiosos.gov (www6.ohiosos.gov)|104.16.134.50|:443... connected.
# HTTP request sent, awaiting response... 200
# Length: 193809289 (185M) [application/octet]
# Saving to: ‘f?p=VOTERFTP:DOWNLOAD::FILE:NO:2:P2_PRODUCT_NUMBER:77’
#
# f?p=VOTERFTP:DOWNLO 100%[===================>] 184.83M  25.9MB/s    in 7.1s
#
# 2021-06-01 10:55:29 (26.2 MB/s) - ‘f?p=VOTERFTP:DOWNLOAD::FILE:NO:2:P2_PRODUCT_NUMBER:77’ saved [193809289/193809289]
#
# --2021-06-01 10:55:29--  https://www6.ohiosos.gov/ords/f?p=VOTERFTP:DOWNLOAD::FILE:NO:2:P2_PRODUCT_NUMBER:78
# Resolving www6.ohiosos.gov (www6.ohiosos.gov)... 104.16.135.50, 104.16.134.50
# Connecting to www6.ohiosos.gov (www6.ohiosos.gov)|104.16.135.50|:443... connected.
# HTTP request sent, awaiting response... 200
# Length: 76326519 (73M) [application/octet]
# Saving to: ‘f?p=VOTERFTP:DOWNLOAD::FILE:NO:2:P2_PRODUCT_NUMBER:78’
#
# f?p=VOTERFTP:DOWNLO 100%[===================>]  72.79M  25.3MB/s    in 2.9s
#
# 2021-06-01 10:55:32 (25.3 MB/s) - ‘f?p=VOTERFTP:DOWNLOAD::FILE:NO:2:P2_PRODUCT_NUMBER:78’ saved [76326519/76326519]
#
# --2021-06-01 10:55:32--  https://www6.ohiosos.gov/ords/f?p=VOTERFTP:DOWNLOAD::FILE:NO:2:P2_PRODUCT_NUMBER:79
# Resolving www6.ohiosos.gov (www6.ohiosos.gov)... 104.16.135.50, 104.16.134.50
# Connecting to www6.ohiosos.gov (www6.ohiosos.gov)|104.16.135.50|:443... connected.
# HTTP request sent, awaiting response... 200
# Length: 33392079 (32M) [application/octet]
# Saving to: ‘f?p=VOTERFTP:DOWNLOAD::FILE:NO:2:P2_PRODUCT_NUMBER:79’
#
# f?p=VOTERFTP:DOWNLO 100%[===================>]  31.84M  23.7MB/s    in 1.3s
#
# 2021-06-01 10:55:34 (23.7 MB/s) - ‘f?p=VOTERFTP:DOWNLOAD::FILE:NO:2:P2_PRODUCT_NUMBER:79’ saved [33392079/33392079]
#
# --2021-06-01 10:55:34--  https://www6.ohiosos.gov/ords/f?p=VOTERFTP:DOWNLOAD::FILE:NO:2:P2_PRODUCT_NUMBER:80
# Resolving www6.ohiosos.gov (www6.ohiosos.gov)... 104.16.134.50, 104.16.135.50
# Connecting to www6.ohiosos.gov (www6.ohiosos.gov)|104.16.134.50|:443... connected.
# HTTP request sent, awaiting response... 200
# Length: 23069983 (22M) [application/octet]
# Saving to: ‘f?p=VOTERFTP:DOWNLOAD::FILE:NO:2:P2_PRODUCT_NUMBER:80’
#
# f?p=VOTERFTP:DOWNLO 100%[===================>]  22.00M  24.0MB/s    in 0.9s
#
# 2021-06-01 10:55:35 (24.0 MB/s) - ‘f?p=VOTERFTP:DOWNLOAD::FILE:NO:2:P2_PRODUCT_NUMBER:80’ saved [23069983/23069983]
#
# --2021-06-01 10:55:35--  https://www6.ohiosos.gov/ords/f?p=VOTERFTP:DOWNLOAD::FILE:NO:2:P2_PRODUCT_NUMBER:81
# Resolving www6.ohiosos.gov (www6.ohiosos.gov)... 104.16.135.50, 104.16.134.50
# Connecting to www6.ohiosos.gov (www6.ohiosos.gov)|104.16.135.50|:443... connected.
# HTTP request sent, awaiting response... 200
# Length: 11160727 (11M) [application/octet]
# Saving to: ‘f?p=VOTERFTP:DOWNLOAD::FILE:NO:2:P2_PRODUCT_NUMBER:81’
#
# f?p=VOTERFTP:DOWNLO 100%[===================>]  10.64M  19.0MB/s    in 0.6s
#
# 2021-06-01 10:55:36 (19.0 MB/s) - ‘f?p=VOTERFTP:DOWNLOAD::FILE:NO:2:P2_PRODUCT_NUMBER:81’ saved [11160727/11160727]
#
# --2021-06-01 10:55:36--  https://www6.ohiosos.gov/ords/f?p=VOTERFTP:DOWNLOAD::FILE:NO:2:P2_PRODUCT_NUMBER:82
# Resolving www6.ohiosos.gov (www6.ohiosos.gov)... 104.16.135.50, 104.16.134.50
# Connecting to www6.ohiosos.gov (www6.ohiosos.gov)|104.16.135.50|:443... connected.
# HTTP request sent, awaiting response... 200
# Length: 4713616 (4.5M) [application/octet]
# Saving to: ‘f?p=VOTERFTP:DOWNLOAD::FILE:NO:2:P2_PRODUCT_NUMBER:82’
#
# f?p=VOTERFTP:DOWNLO 100%[===================>]   4.50M  15.3MB/s    in 0.3s
#
# 2021-06-01 10:55:36 (15.3 MB/s) - ‘f?p=VOTERFTP:DOWNLOAD::FILE:NO:2:P2_PRODUCT_NUMBER:82’ saved [4713616/4713616]
#
# --2021-06-01 10:55:36--  https://www6.ohiosos.gov/ords/f?p=VOTERFTP:DOWNLOAD::FILE:NO:2:P2_PRODUCT_NUMBER:83
# Resolving www6.ohiosos.gov (www6.ohiosos.gov)... 104.16.135.50, 104.16.134.50
# Connecting to www6.ohiosos.gov (www6.ohiosos.gov)|104.16.135.50|:443... connected.
# HTTP request sent, awaiting response... 200
# Length: 92057501 (88M) [application/octet]
# Saving to: ‘f?p=VOTERFTP:DOWNLOAD::FILE:NO:2:P2_PRODUCT_NUMBER:83’
#
# f?p=VOTERFTP:DOWNLO 100%[===================>]  87.79M  27.5MB/s    in 3.3s
#
# 2021-06-01 10:55:40 (26.5 MB/s) - ‘f?p=VOTERFTP:DOWNLOAD::FILE:NO:2:P2_PRODUCT_NUMBER:83’ saved [92057501/92057501]
#
# --2021-06-01 10:55:40--  https://www6.ohiosos.gov/ords/f?p=VOTERFTP:DOWNLOAD::FILE:NO:2:P2_PRODUCT_NUMBER:84
# Resolving www6.ohiosos.gov (www6.ohiosos.gov)... 104.16.135.50, 104.16.134.50
# Connecting to www6.ohiosos.gov (www6.ohiosos.gov)|104.16.135.50|:443... connected.
# HTTP request sent, awaiting response... 200
# Length: 23087006 (22M) [application/octet]
# Saving to: ‘f?p=VOTERFTP:DOWNLOAD::FILE:NO:2:P2_PRODUCT_NUMBER:84’
#
# f?p=VOTERFTP:DOWNLO 100%[===================>]  22.02M  23.7MB/s    in 0.9s
#
# 2021-06-01 10:55:42 (23.7 MB/s) - ‘f?p=VOTERFTP:DOWNLOAD::FILE:NO:2:P2_PRODUCT_NUMBER:84’ saved [23087006/23087006]
#
# --2021-06-01 10:55:42--  https://www6.ohiosos.gov/ords/f?p=VOTERFTP:DOWNLOAD::FILE:NO:2:P2_PRODUCT_NUMBER:85
# Resolving www6.ohiosos.gov (www6.ohiosos.gov)... 104.16.135.50, 104.16.134.50
# Connecting to www6.ohiosos.gov (www6.ohiosos.gov)|104.16.135.50|:443... connected.
# HTTP request sent, awaiting response... 200
# Length: 41019134 (39M) [application/octet]
# Saving to: ‘f?p=VOTERFTP:DOWNLOAD::FILE:NO:2:P2_PRODUCT_NUMBER:85’
#
# f?p=VOTERFTP:DOWNLO 100%[===================>]  39.12M  24.3MB/s    in 1.6s
#
# 2021-06-01 10:55:44 (24.3 MB/s) - ‘f?p=VOTERFTP:DOWNLOAD::FILE:NO:2:P2_PRODUCT_NUMBER:85’ saved [41019134/41019134]
#
# --2021-06-01 10:55:44--  https://www6.ohiosos.gov/ords/f?p=VOTERFTP:DOWNLOAD::FILE:NO:2:P2_PRODUCT_NUMBER:86
# Resolving www6.ohiosos.gov (www6.ohiosos.gov)... 104.16.135.50, 104.16.134.50
# Connecting to www6.ohiosos.gov (www6.ohiosos.gov)|104.16.135.50|:443... connected.
# HTTP request sent, awaiting response... 200
# Length: 13351855 (13M) [application/octet]
# Saving to: ‘f?p=VOTERFTP:DOWNLOAD::FILE:NO:2:P2_PRODUCT_NUMBER:86’
#
# f?p=VOTERFTP:DOWNLO 100%[===================>]  12.73M  23.4MB/s    in 0.5s
#
# 2021-06-01 10:55:45 (23.4 MB/s) - ‘f?p=VOTERFTP:DOWNLOAD::FILE:NO:2:P2_PRODUCT_NUMBER:86’ saved [13351855/13351855]
#
# --2021-06-01 10:55:45--  https://www6.ohiosos.gov/ords/f?p=VOTERFTP:DOWNLOAD::FILE:NO:2:P2_PRODUCT_NUMBER:87
# Resolving www6.ohiosos.gov (www6.ohiosos.gov)... 104.16.135.50, 104.16.134.50
# Connecting to www6.ohiosos.gov (www6.ohiosos.gov)|104.16.135.50|:443... connected.
# HTTP request sent, awaiting response... 200
# Length: 50864677 (49M) [application/octet]
# Saving to: ‘f?p=VOTERFTP:DOWNLOAD::FILE:NO:2:P2_PRODUCT_NUMBER:87’
#
# f?p=VOTERFTP:DOWNLO 100%[===================>]  48.51M  24.4MB/s    in 2.0s
#
# 2021-06-01 10:55:47 (24.4 MB/s) - ‘f?p=VOTERFTP:DOWNLOAD::FILE:NO:2:P2_PRODUCT_NUMBER:87’ saved [50864677/50864677]
#
# --2021-06-01 10:55:47--  https://www6.ohiosos.gov/ords/f?p=VOTERFTP:DOWNLOAD::FILE:NO:2:P2_PRODUCT_NUMBER:88
# Resolving www6.ohiosos.gov (www6.ohiosos.gov)... 104.16.135.50, 104.16.134.50
# Connecting to www6.ohiosos.gov (www6.ohiosos.gov)|104.16.135.50|:443... connected.
# HTTP request sent, awaiting response... 200
# Length: 7605670 (7.3M) [application/octet]
# Saving to: ‘f?p=VOTERFTP:DOWNLOAD::FILE:NO:2:P2_PRODUCT_NUMBER:88’
#
# f?p=VOTERFTP:DOWNLO 100%[===================>]   7.25M  20.7MB/s    in 0.4s
#
# 2021-06-01 10:55:48 (20.7 MB/s) - ‘f?p=VOTERFTP:DOWNLOAD::FILE:NO:2:P2_PRODUCT_NUMBER:88’ saved [7605670/7605670]

# %%
import pandas as pd
import os

# %%
# def get_county_dict():
#     with open("ohio_county_code.txt", "r") as f:
#         content = f.readlines()
#     content = [x.strip() for x in content]
#     county_dict = {}
#     for line in content:
#         line = line.strip()
#         split_line = line.split(" ")
#         county_dict[code] = county
#     return county_dict

# %%
folder = "data"
all_data = []
all_df = []

# %%
for file in os.listdir(folder)[44:]:
    filepath = os.path.join(folder, file)
    print(file)
    df1 = pd.read_csv(filepath, header = "infer", encoding='cp1252')
    all_data.append(df1)
df_final2 = pd.concat(all_data, ignore_index=True)
# Out:
# f?p=VOTERFTP:DOWNLOAD::FILE:NO:2:P2_PRODUCT_NUMBER:75
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (58,73,79,103) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# f?p=VOTERFTP:DOWNLOAD::FILE:NO:2:P2_PRODUCT_NUMBER:62
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (96,106) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# f?p=VOTERFTP:DOWNLOAD::FILE:NO:2:P2_PRODUCT_NUMBER:81
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (60,79,96,100,103) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# f?p=VOTERFTP:DOWNLOAD::FILE:NO:2:P2_PRODUCT_NUMBER:68
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (66,67,103) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# f?p=VOTERFTP:DOWNLOAD::FILE:NO:2:P2_PRODUCT_NUMBER:53
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (74,79,82,103) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# f?p=VOTERFTP:DOWNLOAD::FILE:NO:2:P2_PRODUCT_NUMBER:83
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (58,64,67,73,74,78,79,87,93,96,97,100,103) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# f?p=VOTERFTP:DOWNLOAD::FILE:NO:2:P2_PRODUCT_NUMBER:3
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (58,60,73,74,82,96,100) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# f?p=VOTERFTP:DOWNLOAD::FILE:NO:2:P2_PRODUCT_NUMBER:26
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (25,60,79,82,87,103) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# f?p=VOTERFTP:DOWNLOAD::FILE:NO:2:P2_PRODUCT_NUMBER:88
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (58,87) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# f?p=VOTERFTP:DOWNLOAD::FILE:NO:2:P2_PRODUCT_NUMBER:67
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (25,58,64,66,67,74,75,87,93,96,97,100,106) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# f?p=VOTERFTP:DOWNLOAD::FILE:NO:2:P2_PRODUCT_NUMBER:5
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (58,73,74,79,82,87,93,96,100) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# f?p=VOTERFTP:DOWNLOAD::FILE:NO:2:P2_PRODUCT_NUMBER:51
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (25,58,64,73,74,78,79,87,93,96,100) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# f?p=VOTERFTP:DOWNLOAD::FILE:NO:2:P2_PRODUCT_NUMBER:61
# f?p=VOTERFTP:DOWNLOAD::FILE:NO:2:P2_PRODUCT_NUMBER:80
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (25,26,58,64,66,67,73,74,79,93,96,99) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# f?p=VOTERFTP:DOWNLOAD::FILE:NO:2:P2_PRODUCT_NUMBER:82
# f?p=VOTERFTP:DOWNLOAD::FILE:NO:2:P2_PRODUCT_NUMBER:58
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (25,26,58,60,67,74,86,87,100,103) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (60,105) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# f?p=VOTERFTP:DOWNLOAD::FILE:NO:2:P2_PRODUCT_NUMBER:50
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (20,25,58,60,64,66,67,73,74,79,82,96,100,103,106) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# f?p=VOTERFTP:DOWNLOAD::FILE:NO:2:P2_PRODUCT_NUMBER:41
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (60,66,67,73,79,103) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# f?p=VOTERFTP:DOWNLOAD::FILE:NO:2:P2_PRODUCT_NUMBER:84
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (58,64,66,67,73,74,79,96,103) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# f?p=VOTERFTP:DOWNLOAD::FILE:NO:2:P2_PRODUCT_NUMBER:87
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (26,45,60,73,79,96,110) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# f?p=VOTERFTP:DOWNLOAD::FILE:NO:2:P2_PRODUCT_NUMBER:16
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (26,60,66,73,79,106) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# f?p=VOTERFTP:DOWNLOAD::FILE:NO:2:P2_PRODUCT_NUMBER:71
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (58,60,67,73,74,78,79,96,110) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# f?p=VOTERFTP:DOWNLOAD::FILE:NO:2:P2_PRODUCT_NUMBER:15
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (20,25,26,56,58,64,66,67,73,74,79,96,100,106) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# f?p=VOTERFTP:DOWNLOAD::FILE:NO:2:P2_PRODUCT_NUMBER:44
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (20,66,67,73,74,92,93,96,99,103,105) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# f?p=VOTERFTP:DOWNLOAD::FILE:NO:2:P2_PRODUCT_NUMBER:2
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (20,25,26,58,60,64,73,74,79,82,87,93,96,100,103) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# f?p=VOTERFTP:DOWNLOAD::FILE:NO:2:P2_PRODUCT_NUMBER:55
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (58,66,67,74,79,82) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# f?p=VOTERFTP:DOWNLOAD::FILE:NO:2:P2_PRODUCT_NUMBER:37
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (66,67,79,96,110) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# f?p=VOTERFTP:DOWNLOAD::FILE:NO:2:P2_PRODUCT_NUMBER:12
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (34,58,64,66,67,73,74,79,87,93,100) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# f?p=VOTERFTP:DOWNLOAD::FILE:NO:2:P2_PRODUCT_NUMBER:31
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (58,64,66,67,73,74,78,79,82,87,93,96,97,100,103,106,110) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# f?p=VOTERFTP:DOWNLOAD::FILE:NO:2:P2_PRODUCT_NUMBER:22
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (20,58,64,74,82,87,93,96,100,106) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# f?p=VOTERFTP:DOWNLOAD::FILE:NO:2:P2_PRODUCT_NUMBER:23
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (26,58,64,66,67,73,74,79,87,93,96,100) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# f?p=VOTERFTP:DOWNLOAD::FILE:NO:2:P2_PRODUCT_NUMBER:27
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (25,26,58,60,66,67,73,74,79,96) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# f?p=VOTERFTP:DOWNLOAD::FILE:NO:2:P2_PRODUCT_NUMBER:54
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (25,58,60,64,74,82,93,103) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# f?p=VOTERFTP:DOWNLOAD::FILE:NO:2:P2_PRODUCT_NUMBER:18
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (25,58,64,66,67,74,82,87,93,96,103) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# f?p=VOTERFTP:DOWNLOAD::FILE:NO:2:P2_PRODUCT_NUMBER:25
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (20,25,26,58,64,66,67,73,74,75,78,79,82,87,93,96,97,100,106) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# f?p=VOTERFTP:DOWNLOAD::FILE:NO:2:P2_PRODUCT_NUMBER:48
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (20,25,26,60,73,78,79,96,97,103,105) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# f?p=VOTERFTP:DOWNLOAD::FILE:NO:2:P2_PRODUCT_NUMBER:20
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (20,58,60,64,73,74,87,93,100,103) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# f?p=VOTERFTP:DOWNLOAD::FILE:NO:2:P2_PRODUCT_NUMBER:17
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (25,58,64,73,74,79,96,100) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# f?p=VOTERFTP:DOWNLOAD::FILE:NO:2:P2_PRODUCT_NUMBER:85
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (6,19,20,21,22,25,26,56,60,66,67,73,74,79,87,93,96,100,103,106,110) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# f?p=VOTERFTP:DOWNLOAD::FILE:NO:2:P2_PRODUCT_NUMBER:7
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (25,26,58,60,66,67,73,74,79,103) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# f?p=VOTERFTP:DOWNLOAD::FILE:NO:2:P2_PRODUCT_NUMBER:49
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (25,26,58,73,74,79,87,93,96,110) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# f?p=VOTERFTP:DOWNLOAD::FILE:NO:2:P2_PRODUCT_NUMBER:4
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (58,64,66,67,74,82,87,93,96,100,103) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# f?p=VOTERFTP:DOWNLOAD::FILE:NO:2:P2_PRODUCT_NUMBER:52
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (20,25,26,58,64,74,75,82,87,93,96,106) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# f?p=VOTERFTP:DOWNLOAD::FILE:NO:2:P2_PRODUCT_NUMBER:65
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (74,79,93,96,97) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df_final2.to_csv("/content/drive/MyDrive/ohio_voter_data_master2.csv", encoding='utf-8', index=False)

# %%
df_final2.head()

# %%
len(all_data)
# Out:
# 0

# %%
df_final.shape
# Out:
# (691712, 111)

# %%
df_final = pd.concat(all_data, ignore_index=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-a3477c9b2a90> in <module>()
# ----> 1 df_final = pd.concat(all_data, ignore_index=True)
#
# NameError: name 'pd' is not defined

# %%
df
df_final.to_csv("ohio_voter_data_master_2.csv", encoding='utf-8', index=False)

# %%
df.to_csv("ohio_voter_data_master.csv", encoding='utf-8', index=False)

# %%
surnames = open('/content/drive/MyDrive/voter-analysis/surnames_en.csv').read().split(',\n')
surnames.pop(-1)
# Out:
# ''

# %%
surnames_series = pd.Series(surnames[1:], name='surnames')

# %%
#@title Filtering nepali names voters from ohio_voter's main csv file and creating new csv file with just nepali voters
# This is a one-time step. No need to repeat this as dataset is already made.
nep_chunks = []
chunk_size = 5 * 10 ** 5
for chunk in pd.read_csv('/content/drive/MyDrive/voter-analysis/ohio_voter_data_master.csv', chunksize=chunk_size):
  nep_voter_df = chunk[chunk['LAST_NAME'].isin(surnames_series.values)]
  nep_chunks.append(nep_voter_df)

nep_voter_df = pd.concat(nep_chunks, ignore_index=True)
nep_voter_df.to_csv('/content/drive/MyDrive/voter-analysis/nep_voter_ohio_data.csv')
